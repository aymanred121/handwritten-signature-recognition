# %%
import os

if not os.path.isdir("YOLOv7"):
    os.makedirs("YOLOv7")

# %%
# %cd YOLOv7
# Out:
# d:\Nourhan\handwritten-signature-recognition\Signature Detection Task\Models\YOLOv7

# %%
#! git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...

# %%
# %cd yolov7
# Out:
# d:\Nourhan\handwritten-signature-recognition\Signature Detection Task\Models\yolov7\yolov7

# %%
#%pip install -r requirements.txt

# %%
# !python train.py --weights yolov7.pt --data "data/custom_signature.yaml" --workers 4 --batch-size 4 --img 640 640 --cfg cfg/training/yolov7_signature.yaml --name yolov7 --epochs 100 --hyp data/hyp.scratch.p5.yaml
# Out:
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
# train: WARNING: Ignoring corrupted image and/or label D:\Nourhan\handwritten-signature-recognition\Signature Detection Task\Models\YOLOv7\yolov7\data\Train\images\1.tif: negative labels
# train: WARNING: Ignoring corrupted image and/or label D:\Nourhan\handwritten-signature-recognition\Signature Detection Task\Models\YOLOv7\yolov7\data\Train\images\10.tif: negative labels
# train: WARNING: Ignoring corrupted image and/or label D:\Nourhan\handwritten-signature-recognition\Signature Detection Task\Models\YOLOv7\yolov7\data\Train\images\100.tif: negative labels
# train: WARNING: Ignoring corrupted image and/or label D:\Nourhan\handwritten-signature-recognition\Signature Detection Task\Models\YOLOv7\yolov7\data\Train\images\101.tif: negative labels
# ...
