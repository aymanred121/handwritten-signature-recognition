# %%
import os

if not os.path.isdir("YOLOv7"):
    os.makedirs("YOLOv7")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd YOLOv7
# Out:
# d:\Nourhan\handwritten-signature-recognition\Signature Detection Task\Models\YOLOv7

# %%
! unzip "/content/drive/MyDrive/DetectionDataset.zip"
# Out:
# Archive:  /content/drive/MyDrive/DetectionDataset.zip
#    creating: Data/Test/
#    creating: Data/Test/images/
#   inflating: Data/Test/images/680.tif
#   inflating: Data/Test/images/681.tif
#   inflating: Data/Test/images/682.tif
#   inflating: Data/Test/images/683.tif
#   inflating: Data/Test/images/684.tif
#   inflating: Data/Test/images/685.tif
#   inflating: Data/Test/images/686.tif
#   inflating: Data/Test/images/687.tif
#   inflating: Data/Test/images/689.tif
#   inflating: Data/Test/images/690.tif
#   inflating: Data/Test/images/691.tif
#   inflating: Data/Test/images/692.tif
#   inflating: Data/Test/images/693.tif
#   inflating: Data/Test/images/694.tif
#   inflating: Data/Test/images/695.tif
#   inflating: Data/Test/images/696.tif
#   inflating: Data/Test/images/697.tif
#   inflating: Data/Test/images/698.tif
#   inflating: Data/Test/images/699.tif
#   inflating: Data/Test/images/700.tif
#   inflating: Data/Test/images/701.tif
#   inflating: Data/Test/images/702.tif
# ...

# %%
! git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1094, done.
# remote: Total 1094 (delta 0), reused 0 (delta 0), pack-reused 1094
# Receiving objects: 100% (1094/1094), 69.89 MiB | 22.95 MiB/s, done.
# Resolving deltas: 100% (517/517), done.

# %%
# %cd yolov7
# Out:
# d:\Nourhan\handwritten-signature-recognition\Signature Detection Task\Models\YOLOv7\yolov7

# %%
# %pip install -r requirements.txt

# %%
# !python train.py --weights yolov7.pt --data "data/custom_signature.yaml" --workers 4 --batch-size 4 --img 1024 --cfg cfg/training/yolov7_signature.yaml --name yolov7 --epochs 200 --hyp data/hyp.scratch.custom.yaml
# Out:
# YOLOR 🚀 v0.1-116-g8c0bf3f torch 1.13.0+cu116 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=4, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7_signature.yaml', data='data/custom_signature.yaml', device='', entity=None, epochs=200, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.custom.yaml', image_weights=False, img_size=[1024, 1024], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov72', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=4, upload_dataset=False, v5_metric=False, weights='yolov7.pt', workers=4, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python detect.py --weights runs/train/best.pt --conf 0.25 --img-size 1024 --source data/Test/images/680.tif --name test_img_output
# Out:
# Namespace(weights=['runs/train/best.pt'], source='data/Test/images/680.tif', img_size=1024, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='test_img_output', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 1 signature, Done. (2533.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\test_img_output5\680.tif
# Done. (2.573s)
# YOLOR  2022-12-21 torch 1.13.1+cpu CPU
#
# ...
